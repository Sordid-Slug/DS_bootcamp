# %% [markdown]
# # Day 08. Exercise 05
# # Clustering

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# 1. Read the file [`regression.csv`](https://drive.google.com/file/d/1fzOPkuXoxLleOsvNVCT0m-LKxlid33ma/view?usp=sharing) to a dataframe.
# 2. Remove the `pageviews`, we will cluster the users only by the number of the commits and their average difference.

# %%
df = pd.read_csv('../data/regression.csv').drop('pageviews', axis=1)

# %%
df
# Out:
#         uid  num_commits   AVG(diff)
# 0    user_1           62  -64.400000
# 1   user_10           20  -74.800000
# 2   user_14           61 -159.000000
# 3   user_17           51  -61.600000
# 4   user_18            5   -5.666667
# 5   user_19          118  -98.750000
# 6   user_21           65  -95.500000
# 7   user_25           79  -92.600000
# 8   user_28           60  -86.400000
# 9    user_3           18 -105.400000
# 10  user_30           34 -145.250000
# 11  user_11            7   -2.000000
# 12  user_12           86  -89.000000
# 13  user_13           52  -48.500000
# 14  user_15           23  -17.500000
# 15  user_16           41  -39.333333
# 16   user_2           46 -137.200000
# 17  user_20           57  -27.000000
# 18  user_22            5 -141.400000
# 19  user_23            6  -84.000000
# 20  user_24           37 -223.600000
# 21  user_26           36  -52.333333
# 22  user_27           27   -5.333333
# 23  user_29           51 -157.400000
# 24  user_31          128 -104.750000
# 25   user_4           40 -175.600000
# 26   user_6           15  -62.600000
# 27   user_7            8 -115.500000
# 28   user_8           71 -160.400000

# %%
def optimize_params(model_class, X, optimizing_param, range_p, **model_kwargs):
    
    cluster_list = [f'cluster{val}' for val in range_p]
    cluster_list = [cluster_list[i:i+2] for i in range(0, len(cluster_list), 2)]
    grid = [
        *cluster_list,
        ['score', 'score']
    ]
    
    fig, axis = plt.subplot_mosaic(grid, figsize=(15, 20))
    
    scores = []
    for val, ax in zip(range_p, axis.values()):
        kwargs = {**model_kwargs, optimizing_param : val}

        model = model_class(**kwargs)
        y_pred = model.fit_predict(X)
        
        scores.append(silhouette_score(X, y_pred))
        
        ax.scatter(
            X.iloc[:, 0],
            X.iloc[:, 1], 
            c=y_pred,
            cmap='viridis',
            s=30
        )
        
        ax.set_title(f'param={val}')
    
    best_param = range_p[np.argmax(scores)]
    
    model = model_class(**{**model_kwargs, optimizing_param : best_param})
    y_pred = model.fit_predict(X)
    
    ax = axis['score'].plot(range_p, scores)

# %% [markdown]
# ## 2. KMeans

# %% [markdown]
# 1. Check the documentation about how this algorithm works.
# 2. Use this algorithm to create clusters, use `random_state=21` and `n_clusters=3`.
# 3. Visualize the data on a `scatter plot`.
# 4. Try different values of `n_clusters` and see how your plot will change.
# 5. Calculate the `silhouette_score` (check the docs about the metric).

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
X = df[['num_commits', 'AVG(diff)']]

model = optimize_params(KMeans, X, 'n_clusters', range(2, 8), random_state=21)

# %% [markdown]
# ## 3. DBSCAN

# %% [markdown]
# 1. Check the documentation about how this algorithm works.
# 2. Use this algorithm to create clusters with `eps=20` and `min_samples=2`.
# 3. Visualize the data on a `scatter plot`.
# 4. Try different values of `eps` and `min_samples` and see how your plot will change.
# 5. Calculate the `silhouette_score` (check the docs about the metric).

# %%
from sklearn.cluster import DBSCAN

# %%
optimize_params(
    DBSCAN,
    X,
    'eps',
    range(15, 25),
    min_samples=3
)

# %%
optimize_params(
    DBSCAN,
    X,
    'min_samples',
    range(1, 7),
    eps=22
)

# %% [markdown]
# ## 4. Hierarchical (AgglomerativeClustering)

# %% [markdown]
# 1. Use this algorithm to create clusters with `n_clusters=5`.
# 2. Visualize the data on a `scatter plot`.
# 3. Try different values of `n_clusters` and see how your plot will change.
# 4. Calculate the `silhouette_score`.
# 5. Visualize the `dendrogram`.

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
optimize_params(
    AgglomerativeClustering,
    X,
    'n_clusters',
    range(3, 9),
)

# %%
Z = linkage(df.drop('uid', axis=1), method='ward')

plt.figure(figsize=(15, 8))
dendrogram(Z)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [25.0, 25.0, 35.0, 35.0],
#   [10.0, 10.0, 30.0, 30.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [85.0, 85.0, 95.0, 95.0],
#   [75.0, 75.0, 90.0, 90.0],
#   [65.0, 65.0, 82.5, 82.5],
#   [50.0, 50.0, 73.75, 73.75],
#   [20.0, 20.0, 61.875, 61.875],
#   [115.0, 115.0, 125.0, 125.0],
#   [155.0, 155.0, 165.0, 165.0],
#   [145.0, 145.0, 160.0, 160.0],
#   [135.0, 135.0, 152.5, 152.5],
#   [120.0, 120.0, 143.75, 143.75],
#   [105.0, 105.0, 131.875, 131.875],
#   [185.0, 185.0, 195.0, 195.0],
#   [175.0, 175.0, 190.0, 190.0],
#   [215.0, 215.0, 225.0, 225.0],
#   [205.0, 205.0, 220.0, 220.0],
#   [182.5, 182.5, 212.5, 212.5],
#   [235.0, 235.0, 245.0, 245.0],
#   [255.0, 255.0, 265.0, 265.0],
#   [275.0, 275.0, 285.0, 285.0],
#   [260.0, 260.0, 280.0, 280.0],
#   [240.0, 240.0, 270.0, 270.0],
#   [197.5, 197.5, 255.0, 255.0],
#   [118.4375, 118.4375, 226.25, 226.25],
#   [40.9375, 40.9375, 172.34375, 172.34375]],
#  'dcoord': [[0.0,
#    np.float64(4.176654695380556),
#    np.float64(4.176654695380556),
#    0.0],
#   [0.0, np.float64(12.807332968958752), np.float64(12.807332968958752), 0.0],
#   [np.float64(4.176654695380556),
#    np.float64(28.931192317097626),
#    np.float64(28.931192317097626),
#    np.float64(12.807332968958752)],
#   [0.0, np.float64(11.35077089893017), np.float64(11.35077089893017), 0.0],
#   [0.0, np.float64(13.92838827718412), np.float64(13.92838827718412), 0.0],
#   [0.0,
#    np.float64(15.889665870668315),
#    np.float64(15.889665870668315),
#    np.float64(13.92838827718412)],
#   [0.0,
#    np.float64(29.621766896558928),
#    np.float64(29.621766896558928),
#    np.float64(15.889665870668315)],
#   [np.float64(11.35077089893017),
#    np.float64(38.28989084263287),
#    np.float64(38.28989084263287),
#    np.float64(29.621766896558928)],
#   [np.float64(28.931192317097626),
#    np.float64(117.55906710781291),
#    np.float64(117.55906710781291),
#    np.float64(38.28989084263287)],
#   [0.0, np.float64(14.450000000000006), np.float64(14.450000000000006), 0.0],
#   [0.0, np.float64(10.097524449091472), np.float64(10.097524449091472), 0.0],
#   [0.0,
#    np.float64(17.52293734889597),
#    np.float64(17.52293734889597),
#    np.float64(10.097524449091472)],
#   [0.0,
#    np.float64(32.83544832443538),
#    np.float64(32.83544832443538),
#    np.float64(17.52293734889597)],
#   [np.float64(14.450000000000006),
#    np.float64(44.01751545313147),
#    np.float64(44.01751545313147),
#    np.float64(32.83544832443538)],
#   [0.0,
#    np.float64(90.50297614154016),
#    np.float64(90.50297614154016),
#    np.float64(44.01751545313147)],
#   [0.0, np.float64(13.184839779079603), np.float64(13.184839779079603), 0.0],
#   [0.0,
#    np.float64(22.10098037041193),
#    np.float64(22.10098037041193),
#    np.float64(13.184839779079603)],
#   [0.0, np.float64(14.21302219797042), np.float64(14.21302219797042), 0.0],
#   [0.0,
#    np.float64(36.912554323247086),
#    np.float64(36.912554323247086),
#    np.float64(14.21302219797042)],
#   [np.float64(22.10098037041193),
#    np.float64(81.55327502109691),
#    np.float64(81.55327502109691),
#    np.float64(36.912554323247086)],
#   [0.0, np.float64(11.661903789690601), np.float64(11.661903789690601), 0.0],
#   [0.0, np.float64(7.871467461661768), np.float64(7.871467461661768), 0.0],
#   [0.0, np.float64(10.383159442096606), np.float64(10.383159442096606), 0.0],
#   [np.float64(7.871467461661768),
#    np.float64(28.2850667314044),
#    np.float64(28.2850667314044),
#    np.float64(10.383159442096606)],
#   [np.float64(11.661903789690601),
#    np.float64(84.35663380355255),
#    np.float64(84.35663380355255),
#    np.float64(28.2850667314044)],
#   [np.float64(81.55327502109691),
#    np.float64(189.54985711768109),
#    np.float64(189.54985711768109),
#    np.float64(84.35663380355255)],
#   [np.float64(90.50297614154016),
#    np.float64(207.05761263444208),
#    np.float64(207.05761263444208),
#    np.float64(189.54985711768109)],
#   [np.float64(117.55906710781291),
#    np.float64(326.6145753527071),
#    np.float64(326.6145753527071),
#    np.float64(207.05761263444208)]],
#  'ivl': ['4',
#   '11',
#   '14',
#   '22',
#   '0',
#   '3',
#   '17',
#   '13',
#   '15',
#   '21',
#   '20',
#   '10',
#   '16',
#   '25',
#   '23',
#   '2',
#   '28',
#   '19',
#   '1',
#   '26',
#   '18',
#   '9',
#   '27',
#   '5',
#   '24',
#   '7',
#   '12',
#   '6',
#   '8'],
#  'leaves': [4,
#   11,
#   14,
#   22,
#   0,
#   3,
#   17,
#   13,
#   15,
#   21,
#   20,
#   10,
#   16,
#   25,
#   23,
#   2,
#   28,
#   19,
#   1,
#   26,
#   18,
#   9,
#   27,
#   5,
#   24,
#   7,
#   12,
#   6,
#   8],
#  'color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2']}

# %% [markdown]
# ## 5. Function

# %% [markdown]
# Write a function that:
# 1. Takes as arguments: model class of clustering, its parameters, the name of the parameter for optimization, the range of the parameter values to try.
# 2. Tries different values from the given parameter range and calculates the `silhouette_score` for each value from the range.
# 3. Finds out the best value for the parameter in the range.
# 4. Returns two subplots:
#
#
# - - the first shows how the `silhouette_score` changes depending on the value of the parameter,
# - - the second visualizes the data on a `scatter plot` using the clustering model with the best value of the parameter.
