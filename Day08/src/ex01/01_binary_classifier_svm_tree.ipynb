# %% [markdown]
# # Day 08. Exercise 01
# # Binary classifier. SVM. Decision tree

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## 1. Preprocessing and logreg visualization

# %% [markdown]
# Read the file `am_pm.csv` to a dataframe from the previous exercise.

# %% [markdown]
# 1. Draw a plot where the x-axis is `am`, the y-axis is `pm`, dots are the days, color depends on the target.
# 2. Add the decision boundary of logistic regression to the plot.
# 3. Draw the same plot (with the boundary), but the color should depend this time on the predictions.
#
# Now it should be clear for you how the logistic regression works.

# %%
df = pd.read_csv('../data/am_pm.csv', parse_dates=['date'])

# %%
features = df[['am', 'pm']]
target = df['target']

model = LogisticRegression(
    fit_intercept=False,
    random_state=21
)

model.fit(
    X=features,
    y=target
)
# Out:
# LogisticRegression(fit_intercept=False, random_state=21)

# %%
from sklearn.inspection import DecisionBoundaryDisplay
from matplotlib.colors import ListedColormap

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8), sharey=True)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='target',
    ax=ax1
)

ax1.set(
    xlabel='Number of commits before midday',
    ylabel='Number of commits after midday'
)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='predict',
)

ax2.set(
    xlabel='Number of commits before midday',
    ylabel=None
)
plt.suptitle('Commits distribution by type and time of day')

colors = {
    'Working_day' : 'blue',
    'Weekend' : 'orange'
}

cmap = ListedColormap([color for color in colors.values()])
for ax in (ax1, ax2):
    disp = DecisionBoundaryDisplay.from_estimator(
        model,
        features,
        response_method='predict',
        cmap=cmap,
        plot_method='pcolormesh',
        alpha=0.4,
        ax=ax
    )
plt.show()

ax1.grid()
ax2.grid()
plt.tight_layout()

# %% [markdown]
# ## 2. Standardizing and logreg

# %% [markdown]
# Linear models can be sensitive to the scale of your variables. You make it easier for them to find the optimal solution when you scale your features.
#
# 1. Apply `StandardScaler` to `X` and train logistic regression again with the same parameters.
# 2. Calculate `accuracy` for the new model. Did it get better than a naive classifier with the most popular class?
# 3. Draw the plots that were described above but for the new model.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
model_scaled = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        fit_intercept=False,
        random_state=21
    )
)

model_scaled.fit(features, target)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(fit_intercept=False, random_state=21))])

# %%
df['scaled_predict'] = model_scaled.predict(features)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8), sharey=True)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='target',
    ax=ax1
)

ax1.set(
    xlabel='Number of commits before midday',
    ylabel='Number of commits after midday'
)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='scaled_predict',
)

ax2.set(
    xlabel='Number of commits before midday',
    ylabel=None
)
plt.suptitle('Commits distribution by type and time of day')

colors = {
    'Working_day' : 'blue',
    'Weekend' : 'orange'
}

cmap = ListedColormap([color for color in colors.values()])
for ax in (ax1, ax2):
    disp = DecisionBoundaryDisplay.from_estimator(
        model_scaled,
        features,
        response_method='predict',
        cmap=cmap,
        plot_method='pcolormesh',
        alpha=0.4,
        ax=ax
    )
plt.show()

ax1.grid()
ax2.grid()
plt.tight_layout()

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(target, df['scaled_predict'])
# Out:
# 0.7428571428571429

# %% [markdown]
# ## 3. SVM

# %% [markdown]
# 1. Apply `SVC` model to the scaled dataframe using parameters `probability=True`, `random_state=21`.
# 2. Calculate `accuracy`.
# 3. Try different kernels, find the best in terms of accuracy.
# 4. Draw both plots again with the decisions boundary to see how this algorithm works.

# %%
from sklearn.svm import SVC

# %%
model_SVC = make_pipeline(
    StandardScaler(),
    SVC(
        random_state=21,
        probability=True,
        kernel='rbf'
    )
)

model_SVC.fit(features, target)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(probability=True, random_state=21))])

# %%
df['predict'] = model_SVC.predict(features)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8), sharey=True)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='target',
    ax=ax1
)

ax1.set(
    xlabel='Number of commits before midday',
    ylabel='Number of commits after midday'
)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='predict',
)

ax2.set(
    xlabel='Number of commits before midday',
    ylabel=None
)
plt.suptitle('Commits distribution by type and time of day')

colors = {
    'Working_day' : 'blue',
    'Weekend' : 'orange'
}

cmap = ListedColormap([color for color in colors.values()])
for ax in (ax1, ax2):
    disp = DecisionBoundaryDisplay.from_estimator(
        model_SVC,
        features,
        response_method='predict',
        cmap=cmap,
        plot_method='contourf',
        alpha=0.4,
        ax=ax
    )
plt.show()

ax1.grid()
ax2.grid()
plt.tight_layout()

# %%
accuracy_score(target, df['predict'])
# Out:
# 0.7428571428571429

# %% [markdown]
# ## 4. Decision tree

# %% [markdown]
# 1. Apply `DecisionTreeClassifier` to the scaled dataframe using parameters `max_depth=4`, `random_state=42`.
# 2. Calculate accuracy.
# 3. Try different values of `max_depth`.
# 4. Draw both plots again with the decisions boundary to see how this algorithm works.
# 5. Using method `.plot_tree()` visualize the decision tree itself. It is another way of thinking about how the algorithm works.
# 6. How many leaves in the visualized tree label days as working days? Put your answer in the markdown cell in the end of the section.

# %%
from sklearn.tree import (
    DecisionTreeClassifier,
    plot_tree
)

# %%
model_tree = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier(
        random_state=42,
        max_depth=4
    )
)

model_tree.fit(features, target)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(max_depth=4, random_state=42))])

# %%
df['tree'] = model_tree.predict(features)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8), sharey=True)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='target',
    ax=ax1
)

ax1.set(
    xlabel='Number of commits before midday',
    ylabel='Number of commits after midday'
)

sns.scatterplot(
    data=df,
    x='am',
    y='pm',
    hue='tree',
)

ax2.set(
    xlabel='Number of commits before midday',
    ylabel=None
)
plt.suptitle('Commits distribution by type and time of day')

colors = {
    'Working_day' : 'blue',
    'Weekend' : 'orange'
}

cmap = ListedColormap([color for color in colors.values()])
for ax in (ax1, ax2):
    disp = DecisionBoundaryDisplay.from_estimator(
        model_tree,
        features,
        response_method='predict',
        cmap=cmap,
        plot_method='contourf',
        alpha=0.4,
        ax=ax
    )
plt.show()

ax1.grid()
ax2.grid()
plt.tight_layout()

# %%
accuracy_score(target, df['tree'])
# Out:
# 0.9428571428571428

# %%
print(model_tree.classes_)
# Out:
# ['weekend' 'working_day']

# %%
plt.figure(figsize=(15, 8))

plot_tree(
    model_tree.named_steps['decisiontreeclassifier'],
    filled=True,
    feature_names=model_tree.feature_names_in_,
    class_names=['working_day', 'weekend']
)
# Out:
# [Text(0.40625, 0.9, 'pm <= -0.121\ngini = 0.408\nsamples = 35\nvalue = [10, 25]\nclass = weekend'),
#  Text(0.125, 0.7, 'pm <= -0.705\ngini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = weekend'),
#  Text(0.265625, 0.8, 'True  '),
#  Text(0.0625, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = weekend'),
#  Text(0.1875, 0.5, 'pm <= -0.651\ngini = 0.291\nsamples = 17\nvalue = [3, 14]\nclass = weekend'),
#  Text(0.125, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = working_day'),
#  Text(0.25, 0.3, 'am <= -0.013\ngini = 0.219\nsamples = 16\nvalue = [2, 14]\nclass = weekend'),
#  Text(0.1875, 0.1, 'gini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = weekend'),
#  Text(0.3125, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = weekend'),
#  Text(0.6875, 0.7, 'pm <= 0.9\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = working_day'),
#  Text(0.546875, 0.8, '  False'),
# ...

# %% [markdown]
# there are 4 leaves as working day
